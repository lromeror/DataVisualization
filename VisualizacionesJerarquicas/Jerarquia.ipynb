# %% [markdown]
# <a href="https://colab.research.google.com/github/lromeror/DataVisualization/blob/main/VisualizacionesJerarquicas/Jerarquia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
dfpaises=pd.read_csv('https://raw.githubusercontent.com/lromeror/DataVisualization/main/VisualMultiVariables/paises_vida.csv')
dfpaises=dfpaises.dropna()
df2007=dfpaises[dfpaises["year"]==2007]
df2007
# Out:
#       index             country continent  year  lifeExp       pop  \
# 11       11         Afghanistan      Asia  2007   43.828  31889923
# 23       23             Albania    Europe  2007   76.423   3600523
# 35       35             Algeria    Africa  2007   72.301  33333216
# 47       47              Angola    Africa  2007   42.731  12420476
# 59       59           Argentina  Americas  2007   75.320  40301927
# ...     ...                 ...       ...   ...      ...       ...
# 1655   1655             Vietnam      Asia  2007   74.249  85262356
# 1667   1667  West Bank and Gaza      Asia  2007   73.422   4018332
# 1679   1679         Yemen, Rep.      Asia  2007   62.698  22211743
# 1691   1691              Zambia    Africa  2007   42.384  11746035
# 1703   1703            Zimbabwe    Africa  2007   43.487  12311143
#
#          gdpPercap iso_alpha  iso_num
# 11      974.580338       AFG        4
# 23     5937.029526       ALB        8
# 35     6223.367465       DZA       12
# ...

# %%
fig=px.treemap(df2007,
               path=[px.Constant('World'),'continent','country'],
               values='pop',
               color_continuous_scale='RdBu',
               color='lifeExp')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dfmen=pd.read_csv('https://raw.githubusercontent.com/lromeror/DataVisualization/main/VisualizacionesJerarquicas/marcas_mensajes.csv')
dfmen
# Out:
#               tipo         marca  n_mensajes
# 0          Apparel      Burberry       12767
# 1          Apparel  Calvin Klein        6515
# 2          Apparel    Forever 21       34460
# 3          Apparel       Lacoste        8862
# 4          Apparel          Ross        8139
# ..             ...           ...         ...
# 81  Sporting Goods          Nike       21776
# 82     Supermarket    Albertsons       10649
# 83     Supermarket        Kroger       25714
# 84     Supermarket    WholeFoods       62112
# 85       Warehouse      Samsclub       30504
#
# [86 rows x 3 columns]

# %%
fig=px.treemap(dfmen,
               path=[px.Constant('All'),'tipo','marca'],
               values='n_mensajes')
fig.data[0].textinfo='label+text+value'
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Sunburst
# - mejor para ver proporciones
# - diferencia entre proporciones

# %%
fig = px.sunburst(
    df2007,
    path=[px.Constant("world"), 'continent', 'country'],
    values='pop',
    color='lifeExp', # Codificamos una segunda variable numérica utilizando colores
    color_continuous_scale='RdBu',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dfmar=pd.read_csv('https://raw.githubusercontent.com/lromeror/DataVisualization/main/VisualizacionesJerarquicas/marcas_mensajes.csv')
dfmar
# Out:
#               tipo         marca  n_mensajes
# 0          Apparel      Burberry       12767
# 1          Apparel  Calvin Klein        6515
# 2          Apparel    Forever 21       34460
# 3          Apparel       Lacoste        8862
# 4          Apparel          Ross        8139
# ..             ...           ...         ...
# 81  Sporting Goods          Nike       21776
# 82     Supermarket    Albertsons       10649
# 83     Supermarket        Kroger       25714
# 84     Supermarket    WholeFoods       62112
# 85       Warehouse      Samsclub       30504
#
# [86 rows x 3 columns]

# %%
fig = px.sunburst(
    dfmar,
    path=[px.Constant('Todo'),'tipo', 'marca'],
    values='n_mensajes'
)
# fig.data[0].textinfo = 'label+text+value'
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
